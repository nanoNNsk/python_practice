# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
im_shape = 480,640,3
im = np.random.rand(*im_shape)
plt.imshow(im)
plt.show()

# %% [markdown]
# # thai flag

# %%
#thai flag
thai = np.ones((6,9,3))
thai[[0,-1],:,1:] = 0
thai[2:4,:,:2] = 0
plt.imshow(thai)
plt.show()

# %% [markdown]
# # japan flag

# %%
#japan flag
japan = np.ones((600,900,3))
r= 3/5/2*japan.shape[0]
c=[i//2 for i in japan.shape[:2]]
for i in range(japan.shape[0]):
    for j in range(japan.shape[1]):
        if(i-c[0])**2 + (j-c[1])**2 <= r**2:
            japan[i,j,1:]=0
plt.imshow(japan)
plt.show()

# %% [markdown]
# # image read

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\lenovo\anaconda3\lib\site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\lenovo\anaconda3\lib\site-packages (from opencv-python) (1.26.4)

# %%
import cv2

# %%
im = cv2.imread('dragon.jpg')
cv2.imshow('im',im)
cv2.waitKey()
# Out:
# -1

# %%
# !pip install Pillow
# Out:
# Requirement already satisfied: Pillow in c:\users\lenovo\anaconda3\lib\site-packages (10.4.0)

# %%
from PIL import Image
im =Image.open('dragon.jpg')
im =np.array(im)
plt.imshow(im)
plt.show()

# %% [markdown]
# # save image

# %%
im = Image.fromarray(np.uint8(japan*255))
im.save('japan.jpg')

# %%
im2 = Image.fromarray(np.uint8(255-japan*255))
im.save('japan.gif',save_all=True,append_images=[im2,im]*20)

# %% [markdown]
# # test down sampling

# %%
n=3
for i in range(1,n+1):
    plt.subplot(1,n,i)
    s=1/2**(i+1)
    plt.imshow(cv2.resize(im,None,fx=s,fy=s))
    plt.axis('off')
    plt.title(str(s))
plt.show()

# %%
def image2bitplane(img):
    bp=[]
    for c in range(img.shape[2]):
        for i in range(8):
            bp.append(img[:,:,c]//2**i%2)
    return np.array(bp)

def bitplane2image(bp):
    img = np.zeros((bp[0].shape[0],bp[1].shape(1),3))
    for b in range(len(bp)):
        img[:,:,b//8] = img[:,:,b//8] + (bp[b]*2**(b%8))
    return np.uint8(img)

# %% [markdown]
# # create video

# %%
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
framesize = (480,640,3)
vdo_writter = cv2.VideoWriter('Out.mp4',fourcc,30,(framesize[1],framesize[0]))
for i in range(640):
    frame = np.zeros(framesize,np.uint8)
    cv2.circle(frame,(i,200),20,(255,255,255),-1)
    vdo_writter.write(frame)
vdo_writter.release()

# %%
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
framesize = (480,640,3)
vdo_writter = cv2.VideoWriter('red.mp4',fourcc,30,(framesize[1],framesize[0]))
for i in range(640):
    frame = np.zeros(framesize,np.uint8)
    cv2.circle(frame,(i,200),20,(0,0,255),-1)
    vdo_writter.write(frame)
vdo_writter.release()

# %% [markdown]
# # open video

# %%
#cap = cv2.VideoCapture(0)
cap = cv2.VideoCapture('Out.mp4')
while cap.isOpened():
    ret,frame = cap.read()
    if ret:
        cv2.imshow('frame',frame[:,::-1,:])
    if cv2.waitKey(1) == ord('q') or not ret:
        break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # detect color

# %%
A = cv2.imread('dragon.jpg')
tol = 150
color = np.array([233,141,89])
mask = cv2.inRange(A,color-tol,color+tol)
Amask = cv2.bitwise_and(A,A,mask=mask)
cv2.imshow('dragon',A)
cv2.imshow('mask',mask)
cv2.imshow('Amask',Amask)
plt.subplot(1,3,1)
plt.imshow(cv2.cvtColor(A, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.subplot(1,3,2)
plt.imshow(cv2.cvtColor(mask, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.subplot(1,3,3)
plt.imshow(cv2.cvtColor(Amask, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
cv2.waitKey()
cv2.imwrite('mask.png',mask)
cv2.imwrite('Amask.png',Amask)
# Out:
# True

# %%
cap = cv2.VideoCapture('red.mp4')
buffer = None
while True:
    ret,frame = cap.read()
    if not ret or cv2.waitKey(1) == ord('q'):
        break
    if buffer is not None:
        diff = np.mean(cv2.absdiff(frame,buffer),axis=2)
        fg = np.uint8((diff > 0.5*np.max(diff))*255)
        cv2.imshow('diff',np.uint8(diff/np.max(diff)*255))
        cv2.imshow('fg',fg)
    buffer = frame
    cv2.imshow('frame',frame)
cap.release()
cv2.destroyAllWindows()

# %%
cap = cv2.VideoCapture('red.mp4')
bgsubknn = cv2.createBackgroundSubtractorKNN()
bgsubmog = cv2.createBackgroundSubtractorMOG2()
while True:
    ret,frame = cap.read()
    if not ret or cv2.waitKey(1) == ord('q'):
        break
    fgknn = bgsubknn.apply(frame)
    fgmog = bgsubmog.apply(frame)
    cv2.imshow('frame',frame)
    cv2.imshow('fgknn',fgknn)
    cv2.imshow('fgmog',fgmog)
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # test akaze

# %%
import cv2

# อ่านภาพ
img = cv2.imread('dragon.jpg', cv2.IMREAD_GRAYSCALE)

# สร้างตัวตรวจจับ AKAZE
akaze = cv2.AKAZE_create()

# ตรวจจับลักษณะเด่น (keypoints) และคำนวณ descriptors
keypoints, descriptors = akaze.detectAndCompute(img, None)

# วาดลักษณะเด่นบนภาพ
img_with_keypoints = cv2.drawKeypoints(img, keypoints, None, color=(0, 255, 0))

# แสดงภาพ
cv2.imshow('AKAZE Keypoints', img_with_keypoints)
plt.imshow(img_with_keypoints)
plt.axis('off')
plt.show()
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2

# อ่านภาพ
img = cv2.imread('dragon2.jpg',cv2.IMREAD_GRAYSCALE)

# สร้างตัวตรวจจับ AKAZE
akaze = cv2.AKAZE_create()

# ตรวจจับลักษณะเด่น (keypoints) และคำนวณ descriptors
keypoints, descriptors = akaze.detectAndCompute(img, None)

# วาดลักษณะเด่นบนภาพ
img_with_keypoints = cv2.drawKeypoints(img, keypoints, None, color=(0, 255, 0))

# แสดงภาพ
cv2.imshow('AKAZE Keypoints', img_with_keypoints)
plt.imshow(img_with_keypoints)
plt.axis('off')
plt.show()
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2

# อ่านภาพสองภาพ
img1 = cv2.imread('dragon.jpg', cv2.IMREAD_GRAYSCALE)
img2 = cv2.imread('dragon2.jpg', cv2.IMREAD_GRAYSCALE)

# สร้างตัวตรวจจับ AKAZE
akaze = cv2.AKAZE_create()

# ตรวจจับลักษณะเด่นและคำนวณ descriptors สำหรับทั้งสองภาพ
keypoints1, descriptors1 = akaze.detectAndCompute(img1, None)
keypoints2, descriptors2 = akaze.detectAndCompute(img2, None)

# สร้างตัวจับคู่ BFMatcher
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)

# จับคู่ descriptors ระหว่างสองภาพ
matches = bf.match(descriptors1, descriptors2)

# จัดเรียง matches ตามระยะทาง (distance)
matches = sorted(matches, key=lambda x: x.distance)

# วาด matches บนภาพ
img_matches = cv2.drawMatches(img1, keypoints1, img2, keypoints2, matches[:10], None, flags=cv2.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)

# แสดงภาพที่มีการจับคู่
cv2.imshow('Matches', img_matches)
plt.imshow(img_matches)
plt.axis('off')
plt.show()
cv2.waitKey(0)
cv2.destroyAllWindows()
